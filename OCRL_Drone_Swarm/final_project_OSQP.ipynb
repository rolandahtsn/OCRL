# %%
import Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
import MathOptInterface as MOI
import Ipopt 
import FiniteDiff
import ForwardDiff as FD
import Convex as cvx 
import ECOS
using LinearAlgebra
using Plots
using Random
using JLD2
using Test
import MeshCat as mc 
using Statistics
using ControlSystems
using SparseArrays
using OSQP
using Pkg
using PyCall
using Printf
Pkg.build("PyCall")

project_dir = pwd()
font_path = joinpath(project_dir, "font")
pushfirst!(PyVector(pyimport("sys")."path"), font_path)
@pyimport letters as letters
# Out:
#   Activating environment at `~/Courses/Optimal_Control/Final_Project/Project.toml`
#     Building Conda ─→ `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/51cab8e982c5b598eea9c8ceaced4b58d9dd37c9/build.log`
#     Building PyCall → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/9816a3826b0ebf49ab4926e2b18842ad8b5c8f04/build.log`

# %%
include(joinpath(@__DIR__, "utils","quadrotor.jl"))

function discrete_dynamics(params::NamedTuple, x::Vector, u)
    # discrete dynamics
    # x - state 
    # u - control 
    # dt comes from params.model.dt 
    return rk4(params.model, quadrotor_dynamics, x, u, params.model.dt)
end
# Out:
# discrete_dynamics (generic function with 1 method)

# %% [markdown]
# ### Problem Initialization

# %%
# problem size 
nx = 12
nu = 4
dt = 0.05 
tf = 10
t_vec = 0:dt:tf 
N = length(t_vec)

nt = Int(tf/dt)+1    # number of time steps
thist = Array(range(0,dt*(nt-1), step=dt));

# tracking cost function
Q = 1*diagm([1*ones(3);.1*ones(3);1*ones(3);.1*ones(3)])
R = .1*diagm(ones(nu))
Qf = 10*Q 

# dynamics parameters (these are estimated)
m = 0.5
g = 9.81
model = (mass=m,
        J=Diagonal([0.0023, 0.0023, 0.004]),
        gravity=[0,0,-g],
        L=0.1750,
        kf=1.0,
        km=0.0245,dt = dt)


# the params needed by iLQR 
params = (
    N = N, 
    nx = nx, 
    nu = nu, 
    Q = Q, 
    R = R, 
    Qf = Qf, 
    model = model
)

# Linearized hovering dynamics
x_hover = zeros(nx)
u_hover = [0.25*m*g; 0.25*m*g;0.25*m*g; 0.25*m*g]

# Find A and B matrix
A = FD.jacobian(dx->discrete_dynamics(params,dx,u_hover),x_hover);
B = FD.jacobian(du->discrete_dynamics(params,x_hover,du),u_hover);

#Thrust limits
umin = [0.2*m*g; 0.2*m*g; 0.2*m*g; 0.2*m*g];
umax = [0.6*m*g; 0.6*m*g; 0.6*m*g; 0.6*m*g];


# Cost weights
Q = Array(2.0*I(nx));
R = Array(.01*I(nu));
Qn = Array(1.0*I(nx));

# %%
goal_positions = letters.Letters(text="OCRL", height=2, start=[0,0,0], viz=false).positions
n_drones = size(goal_positions)[1]
# Out:
# 26

# %%
#Build QP matrices for OSQP
nh = 20 #one second horizon at 20Hz
U = kron(Diagonal(I,nh), [I zeros(nu,nx)]) #Matrix that picks out all u
Θ = kron(Diagonal(I,nh), [0 0 0 0 1 0 0 0]) #Matrix that picks out all x3 (θ)

# Big [R1 0 0, 0 Q2 0, ....]matrix also used for LQR
H = sparse([kron(Diagonal(I,nh-1),[R zeros(nu,nx); zeros(nx,nu) Q]) zeros((nx+nu)*(nh-1), nx+nu); zeros(nx+nu,(nx+nu)*(nh-1)) [R zeros(nu,nx); zeros(nx,nu) Qn]])
b = zeros((n_drones, nh*(nx+nu)))
b = [b[i,:] for i in 1:size(b,1)]

# [AB-I, AB-I, ...] also used for LQR
C = sparse([[B -I zeros(nx,(nh-1)*(nu+nx))]; zeros(nx*(nh-1),nu) [kron(Diagonal(I,nh-1), [A B]) zeros((nh-1)*nx,nx)] + [zeros((nh-1)*nx,nx) kron(Diagonal(I,nh-1),[zeros(nx,nu) Diagonal(-I,nx)])]])

# Dynamics + Thrust limit constraints
min_dist = .5
D = [C; U]

lb = repeat([zeros(nx*nh); kron(ones(nh),umin-u_hover)]', outer = n_drones)
lb = [lb[i,:] for i in 1:size(lb,1)]

ub = repeat([zeros(nx*nh); kron(ones(nh),umax-u_hover)]', outer = n_drones)
ub = [ub[i,:] for i in 1:size(ub,1)]

# Dynamics + thrust limit + bound constraint on θ to keep the system within small-angle approximation
# D = [C; U; Θ]
# lb = [zeros(nx*nh); kron(ones(nh),umin-u_hover); -0.2*ones(nh)]
# ub = [zeros(nx*nh); kron(ones(nh),umax-u_hover); 0.2*ones(nh)]

probs = OSQP.Model[]
for i = 1:n_drones
    prob =  OSQP.Model()
    err1 = OSQP.setup!(prob; P=H, q=b[i], A=D, l=lb[i], u=ub[i], verbose=true)
    push!(probs, prob)
end
# Out:
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off
#
# -----------------------------------------------------------------
#            OSQP v0.6.2  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 320, constraints m = 320
#           nnz(P) + nnz(A) = 1774
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-03, eps_rel = 1.0e-03,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 4000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: off, time_limit: off

# %%
#MPC Controller
function mpc_controller(t,X,Xref)
    Δu = zeros((n_drones, nu))

    for i = 1:n_drones
        #Update QP problem
        lb[i][1:12] .= -A*X[i]
        ub[i][1:12] .= -A*X[i]

        for j = 1:(nh-1)
            b[i][(nu+(j-1)*(nx+nu)).+(1:nx)] .= -Q*Xref[i]
        end

        b[i][(nu+(nh-1)*(nx+nu)).+(1:nx)] .= -Qn*Xref[i]

        OSQP.update!(probs[i], q=b[i], l=lb[i], u=ub[i])

        #Solve QP
        results = OSQP.solve!(probs[i])

        Δu[i,:] = u_hover + results.x[1:nu]
    end

    Δu = [Δu[i,:] for i in 1:size(Δu,1)]
    return Δu
end
# Out:
# mpc_controller (generic function with 1 method)

# %%
function closed_loop(X0, controller,N)
    
    xhist = zeros(n_drones,nx,N)

    U0 = controller(1,X0)
    uhist = zeros(n_drones,nu,N-1)

    for i = 1:n_drones
        uhist[i,:,1] .= U0[i]
        xhist[i,:,1] .= X0[i]
    end
    
    for k = 1:(N-1)
        Xn = xhist[:,:,k]
        Xn = [Xn[i,:] for i in 1:size(Xn,1)]

        Uk = controller(k,Xn)
        for i = 1:n_drones 
            uhist[i,:,k] = max.(min.(umax, Uk[i]), umin) #enforce control limits
            xhist[i,:,k+1] .= discrete_dynamics(params,xhist[i,:,k],uhist[i,:,k])  # TODO Change so real and estimated model are different
        end
    end
    return xhist, uhist
end
# Out:
# closed_loop (generic function with 1 method)

# %%
# goal_positions = letters.Letters(text="O", height=2, start=[0,0,0], viz=false).positions
# n_drones = size(goal_positions)[1]

goal_matrix = zeros(n_drones,12)
goal_matrix[:,1:3] = 2*goal_positions
goal_matrix[:,1] = goal_matrix[:,1] .- 10
goal_matrix = [goal_matrix[i,:] for i in 1:size(goal_matrix,1)]

start_matrix = zeros(n_drones,12)
start_matrix[:,1:3] = 2*randn((n_drones,3))
start_matrix[:,3]   = start_matrix[:,3] .+ 2
start_matrix = [start_matrix[i,:] for i in 1:size(start_matrix,1)]

xhist, uhist = closed_loop(start_matrix, (t,x)->mpc_controller(t,x,goal_matrix), nt);
# Out:
# iter   objective    pri res    dua res    rho        time
#    1  -9.0388e+02   4.23e+00   8.66e+02   1.00e-01   3.45e-04s
#   75  -3.6956e+02   2.04e-04   1.85e-03   1.18e+00   9.57e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -369.5575
# run time:             9.63e-04s
# optimal rho estimate: 9.80e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.1261e+03   4.48e+00   8.94e+02   1.00e-01   3.13e-04s
#   50  -5.7723e+02   3.10e-03   1.30e-02   1.12e+00   7.25e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -577.2292
# run time:             7.30e-04s
# optimal rho estimate: 1.38e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4562e+03   5.22e+00   1.04e+03   1.00e-01   2.66e-04s
#   50  -5.3652e+00   3.78e-03   1.64e-02   1.28e+00   6.52e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -5.3652
# run time:             6.57e-04s
# optimal rho estimate: 1.53e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.6773e+03   1.88e+00   3.07e+02   1.00e-01   2.67e-04s
#   75  -1.7084e+01   1.48e-04   7.20e-03   2.23e+00   8.12e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -17.0843
# run time:             8.16e-04s
# optimal rho estimate: 1.59e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.6834e+03   5.87e+00   9.05e+02   1.00e-01   2.86e-04s
#   50   2.2235e+03   5.86e-04   2.48e-02   1.83e+00   6.56e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    2223.5138
# run time:             6.61e-04s
# optimal rho estimate: 9.87e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4942e+03   4.03e+00   8.04e+02   1.00e-01   2.48e-04s
#  100   7.3347e+02   7.59e-05   2.03e-02   2.66e+00   9.94e-04s
#
# status:               solved
# number of iterations: 100
# optimal objective:    733.4701
# run time:             9.98e-04s
# optimal rho estimate: 5.22e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.1972e+03   3.94e+00   7.86e+02   1.00e-01   2.51e-04s
#   75  -1.3189e+02   5.32e-05   6.86e-03   1.72e+00   7.97e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -131.8877
# run time:             8.01e-04s
# optimal rho estimate: 4.36e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -9.4298e+02   4.95e+00   9.73e+02   1.00e-01   2.61e-04s
#   75   5.9399e+02   1.24e-04   2.96e-03   1.49e+00   8.03e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    593.9896
# run time:             8.07e-04s
# optimal rho estimate: 7.43e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.7518e+02   2.51e+00   5.33e+02   1.00e-01   2.50e-04s
#   50  -1.3761e+02   1.15e-03   4.87e-03   1.03e+00   6.28e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -137.6051
# run time:             6.32e-04s
# optimal rho estimate: 1.18e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.4639e+02   3.48e+00   7.86e+02   1.00e-01   2.52e-04s
#   50  -4.9193e+01   2.18e-03   1.36e-04   1.00e-01   5.98e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -49.1934
# run time:             6.02e-04s
# optimal rho estimate: 7.03e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.2374e+02   4.64e+00   9.27e+02   1.00e-01   2.54e-04s
#   75   1.2200e+02   3.48e-03   4.14e-03   6.92e-01   8.05e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    122.0024
# run time:             8.09e-04s
# optimal rho estimate: 1.24e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.6326e+02   2.91e+00   4.98e+02   1.00e-01   2.61e-04s
#   50   4.5806e+02   4.58e-04   7.28e-03   8.62e-01   6.26e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    458.0563
# run time:             6.30e-04s
# optimal rho estimate: 6.34e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.6187e+01   7.57e-01   1.51e+02   1.00e-01   2.53e-04s
#   50   2.6802e+01   3.77e-05   1.13e-03   1.12e+00   6.26e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    26.8020
# run time:             6.30e-04s
# optimal rho estimate: 5.36e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.4748e+01   3.06e+00   6.11e+02   1.00e-01   2.43e-04s
#   50   2.8287e+02   2.58e-03   7.03e-03   8.91e-01   6.21e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    282.8668
# run time:             6.25e-04s
# optimal rho estimate: 1.05e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -8.0934e+01   5.92e+00   1.15e+03   1.00e-01   2.60e-04s
#   50   7.8697e+02   1.89e-04   3.63e-03   6.69e-01   6.40e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    786.9709
# run time:             6.45e-04s
# optimal rho estimate: 3.22e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.2950e+02   2.26e+00   3.98e+02   1.00e-01   2.50e-04s
#   50   1.5450e+02   6.65e-05   1.49e-03   6.32e-01   6.20e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    154.4957
# run time:             6.25e-04s
# optimal rho estimate: 3.69e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.2374e+02   3.30e+00   7.66e+02   1.00e-01   2.44e-04s
#   50  -2.3131e+02   2.71e-03   3.41e-03   6.00e-01   6.18e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -231.3078
# run time:             6.22e-04s
# optimal rho estimate: 1.06e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.0467e+02   2.21e+00   4.42e+02   1.00e-01   2.62e-04s
#   50   1.6096e+02   1.50e-04   1.07e-02   1.58e+00   6.30e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    160.9640
# run time:             6.35e-04s
# optimal rho estimate: 5.79e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.1798e+02   2.46e+00   5.99e+02   1.00e-01   2.50e-04s
#   50  -3.3406e+02   3.83e-04   7.12e-03   1.18e+00   6.22e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -334.0584
# run time:             6.26e-04s
# optimal rho estimate: 6.16e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.6304e+02   4.16e+00   8.32e+02   1.00e-01   2.74e-04s
#   75   1.3533e+02   1.48e-03   2.62e-03   9.66e-01   8.29e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    135.3287
# run time:             8.34e-04s
# optimal rho estimate: 1.42e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.7518e+02   1.42e+00   3.64e+02   1.00e-01   2.61e-04s
#   75  -1.3637e+02   3.00e-05   1.10e-03   1.53e+00   8.09e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -136.3726
# run time:             8.14e-04s
# optimal rho estimate: 7.23e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.0467e+02   2.99e+00   5.97e+02   1.00e-01   2.45e-04s
#   50   3.9311e+02   1.38e-03   6.34e-04   5.61e-01   6.23e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    393.1136
# run time:             6.27e-04s
# optimal rho estimate: 2.24e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.0360e+03   5.22e+00   1.04e+03   1.00e-01   2.52e-04s
#   50  -4.5507e+01   5.31e-04   7.27e-03   8.65e-01   6.20e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -45.5073
# run time:             6.25e-04s
# optimal rho estimate: 5.64e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.1007e+03   2.24e+00   4.47e+02   1.00e-01   2.51e-04s
#   50  -5.2497e+02   3.12e-04   1.36e-02   1.85e+00   6.21e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -524.9738
# run time:             6.26e-04s
# optimal rho estimate: 1.03e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.2950e+03   2.99e+00   5.97e+02   1.00e-01   2.57e-04s
#   50   5.6824e+02   1.07e-03   3.17e-03   7.08e-01   6.25e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    568.2351
# run time:             6.34e-04s
# optimal rho estimate: 1.34e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4060e+03   5.31e+00   8.12e+02   1.00e-01   2.98e-04s
#   50   2.0035e+03   2.41e-04   1.86e-02   2.01e+00   6.66e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    2003.5249
# run time:             6.70e-04s
# optimal rho estimate: 8.11e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.6956e+02   1.85e-04   1.80e-03   1.18e+00   3.05e-05s
#   25  -3.6956e+02   2.15e-05   9.54e-04   1.18e+00   2.37e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -369.5550
# run time:             2.43e-04s
# optimal rho estimate: 4.44e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.7722e+02   2.67e-03   1.17e-02   1.12e+00   2.02e-05s
#   25  -5.7718e+02   2.18e-04   3.88e-03   1.12e+00   1.91e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -577.1829
# run time:             1.96e-04s
# optimal rho estimate: 6.74e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.3591e+00   3.40e-03   1.64e-02   1.28e+00   1.92e-05s
#   25  -5.2642e+00   3.49e-04   5.88e-03   1.28e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -5.2642
# run time:             1.87e-04s
# optimal rho estimate: 7.79e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.7084e+01   8.16e-05   6.87e-03   2.23e+00   1.84e-05s
#   25  -1.7082e+01   1.29e-05   2.73e-03   2.23e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -17.0823
# run time:             1.85e-04s
# optimal rho estimate: 7.61e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.2235e+03   5.01e-04   2.30e-02   1.83e+00   1.97e-05s
#   25   2.2235e+03   6.98e-05   1.12e-02   1.83e+00   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    2223.4600
# run time:             1.89e-04s
# optimal rho estimate: 5.06e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   7.3347e+02   7.42e-05   1.99e-02   2.66e+00   1.91e-05s
#   25   7.3346e+02   4.22e-05   1.36e-02   2.66e+00   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    733.4620
# run time:             1.90e-04s
# optimal rho estimate: 4.75e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3189e+02   4.97e-05   6.54e-03   1.72e+00   1.85e-05s
#   25  -1.3189e+02   1.61e-05   3.16e-03   1.72e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -131.8913
# run time:             1.87e-04s
# optimal rho estimate: 3.54e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   5.9399e+02   1.14e-04   2.84e-03   1.49e+00   1.84e-05s
#   25   5.9399e+02   1.57e-05   1.53e-03   1.49e+00   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    593.9904
# run time:             1.86e-04s
# optimal rho estimate: 3.68e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3760e+02   1.03e-03   4.58e-03   1.03e+00   2.20e-05s
#   25  -1.3760e+02   7.27e-05   1.61e-03   1.03e+00   2.02e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -137.6001
# run time:             2.06e-04s
# optimal rho estimate: 5.18e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.9158e+01   2.11e-03   1.32e-04   1.00e-01   1.91e-05s
#   25  -4.8666e+01   1.04e-03   6.45e-05   1.00e-01   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -48.6661
# run time:             1.91e-04s
# optimal rho estimate: 7.05e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.2202e+02   3.27e-03   3.93e-03   6.92e-01   1.89e-05s
#   25   1.2207e+02   9.93e-04   1.13e-03   6.92e-01   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    122.0691
# run time:             1.88e-04s
# optimal rho estimate: 1.26e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.5806e+02   3.69e-04   6.87e-03   8.62e-01   1.85e-05s
#   25   4.5806e+02   5.75e-05   2.56e-03   8.62e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    458.0607
# run time:             1.86e-04s
# optimal rho estimate: 3.79e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.6802e+01   2.93e-05   1.09e-03   1.12e+00   1.84e-05s
#   25   2.6802e+01   6.85e-06   5.09e-04   1.12e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    26.8020
# run time:             1.85e-04s
# optimal rho estimate: 3.40e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.8287e+02   2.36e-03   6.55e-03   8.91e-01   1.84e-05s
#   25   2.8289e+02   2.83e-04   2.20e-03   8.91e-01   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    282.8890
# run time:             1.87e-04s
# optimal rho estimate: 6.22e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   7.8698e+02   1.77e-04   3.37e-03   6.69e-01   1.86e-05s
#   25   7.8703e+02   3.87e-05   1.11e-03   6.69e-01   1.88e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    787.0258
# run time:             1.92e-04s
# optimal rho estimate: 2.64e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.5450e+02   5.89e-05   1.41e-03   6.32e-01   1.84e-05s
#   25   1.5452e+02   1.51e-05   4.64e-04   6.32e-01   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    154.5183
# run time:             1.88e-04s
# optimal rho estimate: 3.15e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.3131e+02   2.66e-03   3.25e-03   6.00e-01   1.72e-05s
#   25  -2.3129e+02   4.48e-04   8.51e-04   6.00e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -231.2883
# run time:             1.86e-04s
# optimal rho estimate: 8.64e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.6096e+02   1.32e-04   1.01e-02   1.58e+00   1.83e-05s
#   25   1.6096e+02   2.91e-05   2.86e-03   1.58e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    160.9623
# run time:             1.87e-04s
# optimal rho estimate: 4.93e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.3406e+02   3.17e-04   6.82e-03   1.18e+00   1.79e-05s
#   25  -3.3406e+02   4.69e-05   2.70e-03   1.18e+00   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -334.0586
# run time:             1.86e-04s
# optimal rho estimate: 3.50e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.3533e+02   1.42e-03   2.14e-03   9.66e-01   1.82e-05s
#   25   1.3535e+02   1.01e-03   6.29e-04   9.66e-01   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    135.3530
# run time:             1.90e-04s
# optimal rho estimate: 2.39e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3637e+02   1.63e-05   1.06e-03   1.53e+00   1.78e-05s
#   25  -1.3637e+02   2.89e-06   5.11e-04   1.53e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -136.3726
# run time:             1.88e-04s
# optimal rho estimate: 3.30e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   3.9313e+02   1.29e-03   6.03e-04   5.61e-01   1.80e-05s
#   25   3.9321e+02   2.88e-04   1.01e-04   5.61e-01   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    393.2057
# run time:             1.92e-04s
# optimal rho estimate: 2.57e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.5503e+01   6.71e-04   6.86e-03   8.65e-01   1.80e-05s
#   25  -4.5492e+01   5.63e-05   2.40e-03   8.65e-01   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -45.4924
# run time:             1.88e-04s
# optimal rho estimate: 3.19e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.2498e+02   2.58e-04   1.30e-02   1.85e+00   2.22e-05s
#   25  -5.2498e+02   5.59e-05   6.05e-03   1.85e+00   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -524.9844
# run time:             1.91e-04s
# optimal rho estimate: 6.55e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   5.6825e+02   1.02e-03   7.15e-04   7.08e-01   1.78e-05s
#   25   5.6833e+02   1.21e-04   6.47e-05   7.08e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    568.3259
# run time:             1.86e-04s
# optimal rho estimate: 3.16e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.0035e+03   2.92e-04   1.82e-02   2.01e+00   1.80e-05s
#   25   2.0035e+03   6.66e-05   8.44e-03   2.01e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    2003.5269
# run time:             1.85e-04s
# optimal rho estimate: 6.33e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.6956e+02   8.34e-01   9.89e+02   1.18e+00   3.08e-05s
#   50  -3.7992e+02   4.07e-03   1.67e-03   1.18e+00   3.99e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -379.9242
# run time:             4.04e-04s
# optimal rho estimate: 4.62e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.7718e+02   8.22e-01   9.24e+02   1.12e+00   2.04e-05s
#   50  -5.8820e+02   5.03e-03   2.01e-03   1.12e+00   3.60e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -588.1968
# run time:             3.64e-04s
# optimal rho estimate: 4.49e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.2635e+00   1.71e+00   2.22e+03   1.28e+00   2.03e-05s
#   75  -2.9486e+01   3.22e-03   1.32e-03   1.28e+00   5.32e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -29.4863
# run time:             5.36e-04s
# optimal rho estimate: 4.98e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.7082e+01   3.47e+00   8.05e+03   2.23e+00   1.83e-05s
#   50  -5.4265e+01   2.28e-05   1.99e-03   2.23e+00   3.58e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -54.2654
# run time:             3.62e-04s
# optimal rho estimate: 1.19e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.2235e+03   4.08e+00   7.82e+03   1.83e+00   1.89e-05s
#   50   2.1566e+03   1.88e-04   1.65e-03   1.83e+00   3.58e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    2156.5965
# run time:             3.62e-04s
# optimal rho estimate: 2.16e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   7.3346e+02   3.01e+00   8.37e+03   2.66e+00   1.88e-05s
#   50   6.9411e+02   1.57e-04   3.18e-03   2.66e+00   3.62e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    694.1141
# run time:             3.66e-04s
# optimal rho estimate: 1.90e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3189e+02   1.95e+00   3.49e+03   1.72e+00   1.90e-05s
#   50  -1.5183e+02   5.18e-04   3.83e-03   1.72e+00   3.60e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -151.8315
# run time:             3.65e-04s
# optimal rho estimate: 1.82e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.9399e+02   1.96e+00   2.95e+03   1.49e+00   1.98e-05s
#   25   5.6692e+02   5.45e-03   1.40e-02   1.49e+00   1.89e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    566.9236
# run time:             1.93e-04s
# optimal rho estimate: 2.27e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3760e+02   4.04e-01   4.26e+02   1.03e+00   1.96e-05s
#   25  -1.4110e+02   3.60e-03   6.03e-03   1.03e+00   1.94e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -141.1003
# run time:             1.98e-04s
# optimal rho estimate: 1.88e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.8653e+01   1.67e+00   1.69e+02   1.00e-01   2.03e-05s
#   25  -5.4960e+01   1.91e-03   3.81e-04   1.00e-01   1.99e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -54.9605
# run time:             2.04e-04s
# optimal rho estimate: 3.94e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.2207e+02   3.50e-01   2.52e+02   6.92e-01   2.02e-05s
#   25   1.1483e+02   5.01e-03   6.05e-03   6.92e-01   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    114.8296
# run time:             1.89e-04s
# optimal rho estimate: 1.23e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.5806e+02   1.73e+00   1.55e+03   8.62e-01   1.98e-05s
#   50   4.4656e+02   2.03e-03   1.19e-03   8.62e-01   3.57e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    446.5633
# run time:             3.62e-04s
# optimal rho estimate: 3.30e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.6802e+01   4.71e-01   5.31e+02   1.12e+00   1.90e-05s
#   50   2.5819e+01   2.47e-05   2.96e-03   1.12e+00   3.63e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    25.8189
# run time:             3.67e-04s
# optimal rho estimate: 2.69e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.8289e+02   5.62e-01   5.12e+02   8.91e-01   1.94e-05s
#   50   2.7701e+02   3.37e-03   2.82e-03   8.91e-01   3.64e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    277.0125
# run time:             3.68e-04s
# optimal rho estimate: 1.90e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   7.8703e+02   2.34e+00   1.63e+03   6.69e-01   1.86e-05s
#   50   7.7048e+02   3.21e-05   1.51e-03   6.69e-01   3.65e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    770.4778
# run time:             3.70e-04s
# optimal rho estimate: 2.06e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.5452e+02   1.50e+00   9.79e+02   6.32e-01   1.83e-05s
#   25   1.4830e+02   4.55e-04   4.62e-03   6.32e-01   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    148.3009
# run time:             1.90e-04s
# optimal rho estimate: 3.24e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.3129e+02   7.90e-01   4.88e+02   6.00e-01   1.80e-05s
#   50  -2.3428e+02   2.46e-03   1.06e-03   6.00e-01   3.68e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -234.2793
# run time:             3.72e-04s
# optimal rho estimate: 1.81e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.6096e+02   1.80e+00   2.95e+03   1.58e+00   1.92e-05s
#   50   1.4937e+02   1.10e-04   1.78e-03   1.58e+00   3.62e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    149.3665
# run time:             3.67e-04s
# optimal rho estimate: 1.22e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.3406e+02   8.28e-01   1.00e+03   1.18e+00   1.87e-05s
#   50  -3.3910e+02   9.39e-04   1.89e-03   1.18e+00   3.56e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -339.1018
# run time:             3.61e-04s
# optimal rho estimate: 1.87e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.3535e+02   5.75e-01   5.68e+02   9.66e-01   1.81e-05s
#   50   1.2850e+02   4.84e-03   1.28e-03   9.66e-01   3.70e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    128.5020
# run time:             3.74e-04s
# optimal rho estimate: 3.66e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3637e+02   6.73e-01   1.05e+03   1.53e+00   1.78e-05s
#   25  -1.4003e+02   9.09e-04   6.63e-03   1.53e+00   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -140.0279
# run time:             1.89e-04s
# optimal rho estimate: 1.63e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   3.9321e+02   2.18e+00   1.26e+03   5.61e-01   1.84e-05s
#   25   3.7234e+02   1.77e-03   9.54e-03   5.61e-01   1.89e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    372.3381
# run time:             1.97e-04s
# optimal rho estimate: 6.60e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.5493e+01   1.81e+00   1.57e+03   8.65e-01   1.77e-05s
#   50  -6.6575e+01   2.04e-03   1.41e-03   8.65e-01   3.59e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -66.5752
# run time:             3.63e-04s
# optimal rho estimate: 2.51e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.2498e+02   1.81e+00   3.48e+03   1.85e+00   1.76e-05s
#   25  -5.3854e+02   1.06e-03   1.65e-02   1.85e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -538.5371
# run time:             1.87e-04s
# optimal rho estimate: 1.73e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.6833e+02   3.19e+00   2.31e+03   7.08e-01   1.71e-05s
#   50   5.2079e+02   9.15e-05   1.06e-04   7.08e-01   3.64e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    520.7871
# run time:             3.69e-04s
# optimal rho estimate: 2.16e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.0035e+03   4.23e+00   8.79e+03   2.01e+00   1.71e-05s
#   50   1.9386e+03   8.93e-05   1.91e-03   2.01e+00   3.56e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    1938.5615
# run time:             3.60e-04s
# optimal rho estimate: 1.54e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.7992e+02   9.79e-02   2.31e+02   1.18e+00   2.32e-05s
#   50  -3.9105e+02   3.76e-03   2.85e-03   1.18e+00   3.73e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -391.0478
# run time:             3.78e-04s
# optimal rho estimate: 3.40e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.8820e+02   9.77e-02   2.18e+02   1.12e+00   2.05e-05s
#   75  -5.9995e+02   2.22e-03   7.48e-04   1.12e+00   5.41e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    -599.9534
# run time:             5.45e-04s
# optimal rho estimate: 4.90e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.9486e+01   9.97e-02   2.54e+02   1.28e+00   1.96e-05s
#   50  -5.5308e+01   1.40e-03   2.97e-03   1.28e+00   3.80e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -55.3078
# run time:             3.84e-04s
# optimal rho estimate: 2.20e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.4265e+01   2.65e-01   6.55e+02   2.23e+00   1.90e-05s
#   25  -9.1116e+01   9.42e-05   9.06e-03   2.23e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -91.1162
# run time:             1.89e-04s
# optimal rho estimate: 1.13e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.1566e+03   1.80e-01   6.57e+02   1.83e+00   1.90e-05s
#   25   2.0861e+03   7.51e-04   1.04e-02   1.83e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    2086.1211
# run time:             1.88e-04s
# optimal rho estimate: 1.73e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   6.9411e+02   1.33e-01   7.05e+02   2.66e+00   1.92e-05s
#   25   6.5243e+02   3.44e-04   1.20e-02   2.66e+00   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    652.4340
# run time:             1.92e-04s
# optimal rho estimate: 1.45e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5183e+02   1.00e-01   3.43e+02   1.72e+00   1.92e-05s
#   25  -1.7313e+02   3.90e-03   4.86e-03   1.72e+00   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -173.1309
# run time:             1.89e-04s
# optimal rho estimate: 4.44e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.6692e+02   1.00e-01   2.99e+02   1.49e+00   1.87e-05s
#   25   5.3833e+02   5.15e-04   5.76e-03   1.49e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    538.3330
# run time:             1.88e-04s
# optimal rho estimate: 1.09e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4110e+02   9.76e-02   2.00e+02   1.03e+00   1.93e-05s
#   50  -1.4484e+02   2.49e-03   2.47e-03   1.03e+00   3.59e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    -144.8421
# run time:             3.63e-04s
# optimal rho estimate: 2.45e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.4997e+01   1.90e-01   1.88e+01   1.00e-01   1.84e-05s
#   25  -6.2676e+01   3.23e-03   1.85e-04   1.00e-01   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -62.6756
# run time:             1.90e-04s
# optimal rho estimate: 7.34e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.1482e+02   9.73e-02   1.35e+02   6.92e-01   1.90e-05s
#   75   1.0695e+02   5.17e-03   4.20e-04   6.92e-01   5.37e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    106.9497
# run time:             5.41e-04s
# optimal rho estimate: 4.73e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.4656e+02   9.95e-02   1.71e+02   8.62e-01   1.87e-05s
#   25   4.3451e+02   1.64e-03   2.24e-03   8.62e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    434.5060
# run time:             1.86e-04s
# optimal rho estimate: 2.17e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.5819e+01   9.72e-02   2.18e+02   1.12e+00   1.88e-05s
#   50   2.4807e+01   5.24e-05   2.25e-03   1.12e+00   3.55e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    24.8067
# run time:             3.60e-04s
# optimal rho estimate: 4.52e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.7701e+02   9.78e-02   1.74e+02   8.91e-01   2.22e-05s
#   75   2.7075e+02   7.57e-04   4.31e-04   8.91e-01   5.55e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    270.7452
# run time:             5.59e-04s
# optimal rho estimate: 2.30e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   7.7048e+02   1.95e-01   1.34e+02   6.69e-01   1.80e-05s
#   25   7.5407e+02   4.94e-04   3.52e-03   6.69e-01   1.89e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    754.0695
# run time:             1.94e-04s
# optimal rho estimate: 5.29e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.4830e+02   2.63e-01   1.74e+02   6.32e-01   2.27e-05s
#   25   1.4253e+02   8.98e-05   3.03e-03   6.32e-01   1.88e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    142.5349
# run time:             1.92e-04s
# optimal rho estimate: 3.01e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.3428e+02   9.82e-02   1.18e+02   6.00e-01   1.77e-05s
#   25  -2.3743e+02   2.17e-04   2.01e-03   6.00e-01   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -237.4337
# run time:             1.88e-04s
# optimal rho estimate: 3.91e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.4937e+02   9.98e-02   3.14e+02   1.58e+00   1.82e-05s
#   25   1.3720e+02   6.30e-05   8.16e-03   1.58e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    137.1958
# run time:             1.88e-04s
# optimal rho estimate: 4.29e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.3910e+02   9.83e-02   2.33e+02   1.18e+00   1.79e-05s
#   25  -3.4450e+02   3.82e-03   6.55e-03   1.18e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -344.4978
# run time:             1.87e-04s
# optimal rho estimate: 2.03e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.2850e+02   9.78e-02   1.89e+02   9.66e-01   1.78e-05s
#   75   1.2114e+02   3.50e-03   1.04e-03   9.66e-01   5.39e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    121.1432
# run time:             5.43e-04s
# optimal rho estimate: 3.45e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4003e+02   9.84e-02   3.01e+02   1.53e+00   2.14e-05s
#   25  -1.4388e+02   5.00e-05   7.46e-03   1.53e+00   1.88e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -143.8808
# run time:             1.92e-04s
# optimal rho estimate: 3.59e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   3.7234e+02   6.63e-01   7.43e+02   5.61e-01   1.77e-05s
#   50   3.4602e+02   4.11e-04   1.87e-04   5.61e-01   3.67e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    346.0232
# run time:             3.72e-04s
# optimal rho estimate: 2.30e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.6576e+01   1.01e-01   1.74e+02   8.65e-01   1.70e-05s
#   25  -8.8611e+01   2.97e-04   2.15e-03   8.65e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -88.6109
# run time:             1.86e-04s
# optimal rho estimate: 7.77e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.3854e+02   9.97e-02   3.68e+02   1.85e+00   1.69e-05s
#   25  -5.5282e+02   3.38e-04   6.05e-03   1.85e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -552.8178
# run time:             1.85e-04s
# optimal rho estimate: 1.62e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.2079e+02   6.35e-01   8.98e+02   7.08e-01   1.68e-05s
#   50   4.6205e+02   2.01e-04   2.86e-04   7.08e-01   3.54e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    462.0491
# run time:             3.59e-04s
# optimal rho estimate: 1.97e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.9386e+03   1.87e-01   7.50e+02   2.01e+00   1.64e-05s
#   25   1.8712e+03   5.38e-05   6.48e-03   2.01e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1871.1922
# run time:             1.84e-04s
# optimal rho estimate: 6.17e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.9105e+02   9.95e-02   2.35e+02   1.18e+00   2.06e-05s
#   25  -4.0296e+02   3.76e-03   7.84e-03   1.18e+00   1.91e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -402.9562
# run time:             1.95e-04s
# optimal rho estimate: 2.04e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.9995e+02   9.99e-02   2.23e+02   1.12e+00   1.71e-05s
#   25  -6.1266e+02   4.07e-03   8.11e-03   1.12e+00   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -612.6566
# run time:             1.90e-04s
# optimal rho estimate: 2.02e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.5307e+01   1.08e-01   2.76e+02   1.28e+00   1.75e-05s
#   25  -8.3207e+01   3.39e-03   4.68e-03   1.28e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -83.2066
# run time:             1.86e-04s
# optimal rho estimate: 2.73e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -9.1117e+01   8.16e-01   1.84e+03   2.23e+00   1.57e-05s
#   25  -1.2564e+02   2.48e-04   1.04e-02   2.23e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -125.6432
# run time:             1.83e-04s
# optimal rho estimate: 1.05e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   2.0861e+03   3.78e-01   9.15e+02   1.83e+00   1.69e-05s
#   25   2.0132e+03   7.67e-04   6.57e-03   1.83e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    2013.2417
# run time:             1.86e-04s
# optimal rho estimate: 2.20e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   6.5243e+02   1.88e-01   9.91e+02   2.66e+00   1.68e-05s
#   25   6.0881e+02   1.01e-04   1.22e-02   2.66e+00   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    608.8063
# run time:             1.89e-04s
# optimal rho estimate: 7.77e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.7312e+02   1.24e-01   4.25e+02   1.72e+00   1.65e-05s
#   25  -1.9577e+02   2.02e-03   1.38e-02   1.72e+00   1.91e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -195.7733
# run time:             1.96e-04s
# optimal rho estimate: 1.90e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.3834e+02   1.22e-01   3.62e+02   1.49e+00   1.61e-05s
#   25   5.0821e+02   1.60e-04   1.05e-02   1.49e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    508.2077
# run time:             1.84e-04s
# optimal rho estimate: 4.49e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4484e+02   9.81e-02   2.01e+02   1.03e+00   1.52e-05s
#   25  -1.4882e+02   2.38e-03   2.72e-03   1.03e+00   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -148.8248
# run time:             1.86e-04s
# optimal rho estimate: 2.28e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.2711e+01   2.97e-01   2.95e+01   1.00e-01   1.62e-05s
#   25  -7.0619e+01   3.63e-03   1.97e-04   1.00e-01   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -70.6189
# run time:             1.87e-04s
# optimal rho estimate: 7.53e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.0695e+02   9.76e-02   1.35e+02   6.92e-01   1.57e-05s
#   75   9.8538e+01   5.09e-03   6.04e-04   6.92e-01   5.30e-04s
#
# status:               solved
# number of iterations: 75
# optimal objective:    98.5380
# run time:             5.34e-04s
# optimal rho estimate: 3.92e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.3451e+02   3.49e-01   2.99e+02   8.62e-01   3.98e-05s
#   25   4.2280e+02   1.08e-04   4.21e-03   8.62e-01   2.04e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    422.7956
# run time:             2.09e-04s
# optimal rho estimate: 3.50e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.4807e+01   1.11e-01   2.12e+02   1.12e+00   1.47e-05s
#   50   2.3811e+01   3.28e-05   1.69e-03   1.12e+00   3.65e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    23.8109
# run time:             3.70e-04s
# optimal rho estimate: 4.17e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.7075e+02   9.91e-02   1.76e+02   8.91e-01   1.60e-05s
#   25   2.6401e+02   3.92e-03   5.16e-03   8.91e-01   1.94e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    264.0075
# run time:             1.99e-04s
# optimal rho estimate: 1.51e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   7.5407e+02   5.38e-01   3.61e+02   6.69e-01   1.62e-05s
#   25   7.3871e+02   1.74e-04   1.87e-03   6.69e-01   1.93e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    738.7069
# run time:             1.97e-04s
# optimal rho estimate: 4.32e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.4253e+02   3.23e-01   2.21e+02   6.32e-01   1.60e-05s
#   25   1.3712e+02   9.04e-04   2.92e-03   6.32e-01   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    137.1231
# run time:             1.91e-04s
# optimal rho estimate: 9.74e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.3743e+02   1.21e-01   1.15e+02   6.00e-01   1.61e-05s
#   25  -2.4061e+02   1.29e-04   1.54e-03   6.00e-01   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -240.6102
# run time:             1.92e-04s
# optimal rho estimate: 3.45e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.3720e+02   4.38e-01   6.86e+02   1.58e+00   1.97e-05s
#   25   1.2567e+02   2.46e-03   9.49e-03   1.58e+00   1.90e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    125.6715
# run time:             1.95e-04s
# optimal rho estimate: 2.49e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.4450e+02   9.90e-02   2.34e+02   1.18e+00   1.62e-05s
#   25  -3.5018e+02   1.35e-03   4.20e-03   1.18e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -350.1808
# run time:             1.88e-04s
# optimal rho estimate: 1.51e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.2114e+02   9.84e-02   1.90e+02   9.66e-01   1.67e-05s
#   50   1.1327e+02   2.32e-03   1.40e-03   9.66e-01   3.58e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    113.2710
# run time:             3.63e-04s
# optimal rho estimate: 2.42e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4388e+02   1.38e-01   2.83e+02   1.53e+00   1.52e-05s
#   25  -1.4765e+02   1.59e-03   7.90e-03   1.53e+00   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -147.6528
# run time:             1.86e-04s
# optimal rho estimate: 1.96e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   3.4602e+02   6.00e-01   6.21e+02   5.61e-01   1.61e-05s
#   25   3.1660e+02   9.55e-04   2.94e-03   5.61e-01   1.86e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    316.6041
# run time:             1.91e-04s
# optimal rho estimate: 7.65e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -8.8611e+01   3.95e-01   3.53e+02   8.65e-01   1.54e-05s
#   25  -1.0983e+02   1.23e-04   5.25e-03   8.65e-01   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -109.8306
# run time:             1.84e-04s
# optimal rho estimate: 2.41e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.5282e+02   2.54e-01   4.76e+02   1.85e+00   1.64e-05s
#   25  -5.6714e+02   9.92e-05   9.05e-03   1.85e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -567.1420
# run time:             1.86e-04s
# optimal rho estimate: 7.19e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   4.6205e+02   8.23e-01   7.94e+02   7.08e-01   1.65e-05s
#   25   3.9557e+02   7.57e-04   3.76e-03   7.08e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    395.5658
# run time:             1.85e-04s
# optimal rho estimate: 9.11e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.8712e+03   1.03e+00   2.09e+03   2.01e+00   1.65e-05s
#   25   1.8068e+03   3.16e-04   1.21e-02   2.01e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1806.8187
# run time:             1.85e-04s
# optimal rho estimate: 6.43e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.0295e+02   1.02e-01   2.41e+02   1.18e+00   1.90e-05s
#   25  -4.1566e+02   2.21e-04   7.12e-03   1.18e+00   1.91e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -415.6627
# run time:             1.95e-04s
# optimal rho estimate: 5.20e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.1265e+02   1.02e-01   2.28e+02   1.12e+00   1.75e-05s
#   25  -6.2617e+02   3.47e-04   7.18e-03   1.12e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -626.1671
# run time:             1.85e-04s
# optimal rho estimate: 6.28e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -8.3203e+01   2.24e-01   3.47e+02   1.28e+00   1.63e-05s
#   25  -1.1274e+02   7.48e-04   1.30e-02   1.28e+00   1.90e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -112.7400
# run time:             1.94e-04s
# optimal rho estimate: 7.70e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.2564e+02   7.03e-01   1.58e+03   2.23e+00   1.71e-05s
#   25  -1.5973e+02   2.15e-04   1.02e-02   2.23e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -159.7253
# run time:             1.87e-04s
# optimal rho estimate: 9.89e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.0132e+03   1.04e+00   1.92e+03   1.83e+00   1.61e-05s
#   25   1.9406e+03   3.99e-04   1.33e-02   1.83e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1940.5635
# run time:             1.85e-04s
# optimal rho estimate: 1.12e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   6.0880e+02   7.82e-01   2.09e+03   2.66e+00   1.67e-05s
#   25   5.6504e+02   2.39e-04   1.97e-02   2.66e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    565.0419
# run time:             1.88e-04s
# optimal rho estimate: 4.85e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.9577e+02   5.02e-01   8.61e+02   1.72e+00   1.64e-05s
#   25  -2.1870e+02   1.40e-03   9.15e-03   1.72e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -218.7042
# run time:             1.86e-04s
# optimal rho estimate: 1.95e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   5.0821e+02   5.13e-01   7.78e+02   1.49e+00   1.54e-05s
#   25   4.7790e+02   1.92e-04   7.26e-03   1.49e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    477.8983
# run time:             1.83e-04s
# optimal rho estimate: 5.92e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4882e+02   9.87e-02   2.02e+02   1.03e+00   1.56e-05s
#   25  -1.5304e+02   2.62e-04   6.64e-03   1.03e+00   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -153.0447
# run time:             1.92e-04s
# optimal rho estimate: 4.84e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -7.0636e+01   3.31e-01   3.28e+01   1.00e-01   1.58e-05s
#   25  -7.8457e+01   3.51e-03   1.87e-04   1.00e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -78.4566
# run time:             1.86e-04s
# optimal rho estimate: 7.59e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   9.8538e+01   9.80e-02   1.36e+02   6.92e-01   1.56e-05s
#   50   8.9579e+01   5.39e-03   1.44e-03   6.92e-01   3.54e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    89.5793
# run time:             3.58e-04s
# optimal rho estimate: 2.62e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.2280e+02   3.94e-01   3.39e+02   8.62e-01   1.41e-05s
#   25   4.1125e+02   1.21e-04   5.62e-03   8.62e-01   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    411.2509
# run time:             1.82e-04s
# optimal rho estimate: 2.47e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.3811e+01   9.55e-02   2.14e+02   1.12e+00   1.42e-05s
#   50   2.2779e+01   2.66e-05   1.21e-03   1.12e+00   3.50e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    22.7794
# run time:             3.54e-04s
# optimal rho estimate: 4.50e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.6401e+02   9.99e-02   1.78e+02   8.91e-01   1.44e-05s
#   25   2.5689e+02   2.18e-04   3.56e-03   8.91e-01   1.82e-04s
#
# ...
#    1  -3.5018e+02   2.15e-01   2.62e+02   1.18e+00   1.51e-05s
#   25  -3.5596e+02   9.80e-05   6.96e-03   1.18e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -355.9596
# run time:             1.83e-04s
# optimal rho estimate: 3.15e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.1327e+02   9.93e-02   1.92e+02   9.66e-01   1.59e-05s
#   25   1.0482e+02   4.02e-03   5.16e-03   9.66e-01   1.92e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    104.8196
# run time:             1.96e-04s
# optimal rho estimate: 1.66e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4765e+02   1.52e-01   2.86e+02   1.53e+00   1.50e-05s
#   25  -1.5141e+02   1.26e-04   5.46e-03   1.53e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -151.4091
# run time:             1.85e-04s
# optimal rho estimate: 6.66e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   3.1661e+02   4.93e-01   2.74e+02   5.61e-01   1.54e-05s
#   25   2.9466e+02   1.07e-03   1.41e-03   5.61e-01   1.85e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    294.6579
# run time:             1.89e-04s
# optimal rho estimate: 1.40e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.0983e+02   4.08e-01   3.65e+02   8.65e-01   1.56e-05s
#   25  -1.3070e+02   1.27e-04   6.80e-03   8.65e-01   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -130.7009
# run time:             1.84e-04s
# optimal rho estimate: 2.47e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.6714e+02   4.37e-01   8.03e+02   1.85e+00   1.55e-05s
#   25  -5.8131e+02   1.34e-04   1.12e-02   1.85e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -581.3094
# run time:             1.85e-04s
# optimal rho estimate: 4.67e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   3.9558e+02   7.37e-01   5.22e+02   7.08e-01   1.58e-05s
#   25   3.4801e+02   4.63e-04   2.06e-03   7.08e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    348.0094
# run time:             1.85e-04s
# optimal rho estimate: 1.15e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.8068e+03   9.39e-01   1.88e+03   2.01e+00   1.60e-05s
#   25   1.7444e+03   2.87e-04   1.25e-02   2.01e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1744.3695
# run time:             1.87e-04s
# optimal rho estimate: 7.41e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.1566e+02   1.84e-01   2.35e+02   1.18e+00   1.81e-05s
#   25  -4.2907e+02   1.64e-04   1.00e-02   1.18e+00   1.91e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -429.0677
# run time:             1.95e-04s
# optimal rho estimate: 3.77e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.2617e+02   1.59e-01   2.25e+02   1.12e+00   1.56e-05s
#   25  -6.4051e+02   3.83e-04   8.19e-03   1.12e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -640.5119
# run time:             1.85e-04s
# optimal rho estimate: 6.20e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.1274e+02   4.53e-01   5.86e+02   1.28e+00   1.55e-05s
#   25  -1.4360e+02   8.79e-04   6.79e-03   1.28e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -143.6036
# run time:             1.85e-04s
# optimal rho estimate: 1.16e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5973e+02   5.98e-01   1.41e+03   2.23e+00   1.53e-05s
#   25  -1.9470e+02   1.84e-04   9.19e-03   2.23e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -194.7012
# run time:             1.86e-04s
# optimal rho estimate: 1.30e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.9406e+03   8.85e-01   1.61e+03   1.83e+00   1.63e-05s
#   25   1.8673e+03   2.72e-04   1.54e-02   1.83e+00   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1867.3386
# run time:             1.86e-04s
# optimal rho estimate: 8.14e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   5.6504e+02   6.68e-01   1.76e+03   2.66e+00   1.53e-05s
#   25   5.2041e+02   3.92e-04   1.72e-02   2.66e+00   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    520.4101
# run time:             1.86e-04s
# optimal rho estimate: 1.29e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.1870e+02   4.60e-01   7.80e+02   1.72e+00   1.59e-05s
#   25  -2.4224e+02   1.78e-03   1.29e-02   1.72e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -242.2432
# run time:             1.85e-04s
# optimal rho estimate: 1.86e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.7790e+02   4.39e-01   6.74e+02   1.49e+00   1.43e-05s
#   25   4.4698e+02   1.77e-04   8.49e-03   1.49e+00   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    446.9761
# run time:             1.83e-04s
# optimal rho estimate: 5.27e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5304e+02   9.68e-02   1.98e+02   1.03e+00   1.51e-05s
#   25  -1.5747e+02   3.52e-04   6.60e-03   1.03e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -157.4730
# run time:             1.88e-04s
# optimal rho estimate: 5.62e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -7.8454e+01   3.23e-01   3.20e+01   1.00e-01   1.44e-05s
#   25  -8.6237e+01   3.10e-03   1.63e-04   1.00e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -86.2370
# run time:             1.86e-04s
# optimal rho estimate: 7.21e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   8.9580e+01   9.85e-02   1.36e+02   6.92e-01   1.48e-05s
#   50   8.0096e+01   4.25e-03   9.19e-04   6.92e-01   3.53e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    80.0963
# run time:             3.58e-04s
# optimal rho estimate: 2.90e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.1125e+02   3.32e-01   2.89e+02   8.62e-01   1.47e-05s
#   25   3.9948e+02   4.83e-04   4.49e-03   8.62e-01   1.77e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    399.4790
# run time:             1.82e-04s
# optimal rho estimate: 8.33e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.2779e+01   8.68e-02   1.95e+02   1.12e+00   1.37e-05s
#   25   2.1673e+01   2.17e-05   2.14e-03   1.12e+00   1.77e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    21.6725
# run time:             1.81e-04s
# optimal rho estimate: 2.64e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.5689e+02   1.52e-01   1.69e+02   8.91e-01   1.34e-05s
#   25   2.4951e+02   1.03e-04   4.62e-03   8.91e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    249.5065
# run time:             1.86e-04s
# optimal rho estimate: 2.59e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   7.2348e+02   4.02e-01   2.92e+02   6.69e-01   1.33e-05s
#   25   7.0779e+02   1.26e-04   1.67e-03   6.69e-01   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    707.7916
# run time:             1.87e-04s
# optimal rho estimate: 3.71e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.3178e+02   2.39e-01   1.77e+02   6.32e-01   1.30e-05s
#   25   1.2626e+02   5.95e-05   1.46e-03   6.32e-01   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    126.2607
# run time:             1.87e-04s
# optimal rho estimate: 2.08e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.4378e+02   1.58e-01   1.17e+02   6.00e-01   1.31e-05s
#   25  -2.4706e+02   7.38e-05   3.29e-03   6.00e-01   1.82e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -247.0637
# run time:             1.86e-04s
# optimal rho estimate: 1.78e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.1433e+02   3.30e-01   5.26e+02   1.58e+00   1.30e-05s
#   25   1.0276e+02   1.42e-04   5.84e-03   1.58e+00   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    102.7631
# run time:             1.82e-04s
# optimal rho estimate: 7.59e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -3.5596e+02   1.91e-01   2.38e+02   1.18e+00   1.30e-05s
#   25  -3.6192e+02   2.67e-04   5.02e-03   1.18e+00   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -361.9229
# run time:             1.82e-04s
# optimal rho estimate: 6.12e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.0482e+02   1.00e-01   1.93e+02   9.66e-01   1.33e-05s
#   25   9.5903e+01   3.29e-04   5.58e-03   9.66e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    95.9026
# run time:             1.85e-04s
# optimal rho estimate: 4.57e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5141e+02   1.31e-01   2.94e+02   1.53e+00   1.35e-05s
#   25  -1.5528e+02   8.02e-05   6.17e-03   1.53e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -155.2757
# run time:             1.84e-04s
# optimal rho estimate: 4.98e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.9466e+02   3.08e-01   1.70e+02   5.61e-01   1.36e-05s
#   25   2.7280e+02   3.73e-04   1.62e-03   5.61e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    272.7968
# run time:             1.85e-04s
# optimal rho estimate: 7.80e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.3070e+02   3.43e-01   3.11e+02   8.65e-01   1.39e-05s
#   25  -1.5192e+02   4.49e-04   6.25e-03   8.65e-01   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -151.9177
# run time:             1.83e-04s
# optimal rho estimate: 5.61e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -5.8131e+02   3.70e-01   6.88e+02   1.85e+00   1.48e-05s
#   25  -5.9574e+02   3.61e-04   8.48e-03   1.85e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -595.7408
# run time:             1.83e-04s
# optimal rho estimate: 1.43e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   3.4801e+02   4.57e-01   3.21e+02   7.08e-01   1.51e-05s
#   25   3.0029e+02   2.23e-04   1.80e-03   7.08e-01   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    300.2940
# run time:             1.82e-04s
# optimal rho estimate: 8.01e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   1.7444e+03   7.86e-01   1.57e+03   2.01e+00   1.52e-05s
#   25   1.6819e+03   2.41e-04   1.07e-02   2.01e+00   1.80e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1681.9428
# run time:             1.84e-04s
# optimal rho estimate: 1.04e+00
#
# iter   objective    pri res    dua res    rho        time
#    1  -4.2907e+02   2.13e-01   2.69e+02   1.18e+00   1.62e-05s
#   25  -4.4308e+02   2.97e-04   7.24e-03   1.18e+00   1.88e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -443.0823
# run time:             1.93e-04s
# optimal rho estimate: 5.97e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -6.4051e+02   2.14e-01   2.56e+02   1.12e+00   1.36e-05s
#   25  -6.5551e+02   1.73e-04   7.96e-03   1.12e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -655.5077
# run time:             1.83e-04s
# optimal rho estimate: 4.24e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.4360e+02   3.82e-01   5.04e+02   1.28e+00   1.34e-05s
#   25  -1.7590e+02   6.17e-04   1.32e-02   1.28e+00   1.78e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -175.8952
# run time:             1.82e-04s
# optimal rho estimate: 6.98e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.9470e+02   5.00e-01   1.23e+03   2.23e+00   1.33e-05s
#   25  -2.3115e+02   8.97e-04   1.11e-02   2.23e+00   1.79e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -231.1543
# run time:             1.83e-04s
# optimal rho estimate: 3.10e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   1.8673e+03   7.25e-01   1.32e+03   1.83e+00   1.34e-05s
#   25   1.7921e+03   2.22e-04   1.55e-02   1.83e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    1792.0714
# run time:             1.89e-04s
# optimal rho estimate: 5.78e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   5.2041e+02   5.53e-01   1.48e+03   2.66e+00   1.47e-05s
#   25   4.7413e+02   1.87e-04   1.66e-02   2.66e+00   1.87e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    474.1331
# run time:             1.92e-04s
# optimal rho estimate: 9.14e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -2.4224e+02   3.84e-01   6.60e+02   1.72e+00   1.51e-05s
#   25  -2.6687e+02   4.73e-04   8.86e-03   1.72e+00   1.84e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -266.8664
# run time:             1.88e-04s
# optimal rho estimate: 1.16e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   4.4697e+02   3.64e-01   5.68e+02   1.49e+00   1.47e-05s
#   25   4.1480e+02   1.77e-04   1.18e-02   1.49e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    414.7984
# run time:             1.88e-04s
# optimal rho estimate: 4.48e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -1.5747e+02   9.82e-02   1.97e+02   1.03e+00   1.54e-05s
#   25  -1.6208e+02   9.96e-05   4.28e-03   1.03e+00   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -162.0795
# run time:             1.87e-04s
# optimal rho estimate: 3.71e-01
#
# iter   objective    pri res    dua res    rho        time
#    1  -8.6221e+01   2.93e-01   2.94e+01   1.00e-01   1.56e-05s
#   25  -9.4152e+01   2.56e-03   1.40e-04   1.00e-01   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    -94.1517
# run time:             1.87e-04s
# optimal rho estimate: 6.37e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   8.0096e+01   9.93e-02   1.37e+02   6.92e-01   1.53e-05s
#   25   7.0044e+01   4.70e-03   5.04e-03   6.92e-01   1.81e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    70.0438
# run time:             1.86e-04s
# optimal rho estimate: 1.30e+00
#
# iter   objective    pri res    dua res    rho        time
#    1   3.9948e+02   2.74e-01   2.42e+02   8.62e-01   2.00e-05s
#   25   3.8719e+02   1.51e-04   3.07e-03   8.62e-01   1.83e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    387.1927
# run time:             1.87e-04s
# optimal rho estimate: 5.65e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.1673e+01   6.75e-02   9.40e+01   1.12e+00   1.44e-05s
#   25   2.0470e+01   1.71e-05   3.27e-03   1.12e+00   1.77e-04s
#
# status:               solved
# number of iterations: 25
# optimal objective:    20.4695
# run time:             1.81e-04s
# optimal rho estimate: 1.53e-01
#
# iter   objective    pri res    dua res    rho        time
#    1   2.4951e+02   1.37e-01   1.73e+02   8.91e-01   1.52e-05s
#   50   2.4182e+02   3.64e-05   1.44e-03   8.91e-01   3.59e-04s
#
# status:               solved
# number of iterations: 50
# optimal objective:    241.8189
# run time:             3.63e-04s
# optimal rho estimate: 2.76e-01
#
# i

# %%
x = []
for k = 1:n_drones
    xhist_k = xhist[k,:,:]
    xhist_k = [xhist_k[:,i] for i in 1:size(xhist_k,2)]
    push!(x, xhist_k)
end

display(animate_quadrotor_n(x,x,n_drones, params.model.dt))
# Out:
# ┌ Info: Listening on: 127.0.0.1:8700, thread id: 1
# └ @ HTTP.Servers /home/acantu/.julia/packages/HTTP/vnQzp/src/Servers.jl:382
# ┌ Info: MeshCat server started. You can open the visualizer by visiting the following URL in your browser:
# │ http://127.0.0.1:8700
# └ @ MeshCat /home/acantu/.julia/packages/MeshCat/I6NTX/src/visualizer.jl:63
# MeshCat.DisplayedVisualizer(MeshCat.CoreVisualizer(MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), UInt8[0x83, 0xa7, 0x6f, 0x70, 0x74, 0x69, 0x6f, 0x6e, 0x73, 0x82  …  0x5f, 0x61, 0x6e, 0x69, 0x6d, 0x61, 0x74, 0x69, 0x6f, 0x6e], Dict{String, MeshCat.SceneTrees.SceneNode}("meshcat" => MeshCat.SceneTrees.SceneNode(nothing, nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}("24" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32, 0x34], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "4" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x2f, 0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x34], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "1" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x2f, 0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x31], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "12" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x31, 0x32], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "20" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32, 0x30], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "2" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x2f, 0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "6" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x2f, 0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x36], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "25" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32, 0x35], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "23" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32, 0x33], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}()), "22" => MeshCat.SceneTrees.SceneNode(UInt8[0x83, 0xa6, 0x6f, 0x62, 0x6a, 0x65, 0x63, 0x74, 0x84, 0xaa  …  0x6d, 0x65, 0x73, 0x68, 0x63, 0x61, 0x74, 0x2f, 0x32, 0x32], nothing, Dict{String, Vector{UInt8}}(), nothing, Dict{String, MeshCat.SceneTrees.SceneNode}())…)))), Set{HTTP.WebSockets.WebSocket}(), ip"127.0.0.1", 8700))

# %% [markdown]
# ## Scheduler to avoid Collisions

# %%
min_dist = 0.7
function all_scheduled(start_times)
    for i = 1:n_drones
        if(start_times[i] < 0)
            return false
        end
    end
    return true
end

function all_scheduled_or_blocked(start_times)
    for i = 1:n_drones
        if(start_times[i] == -1)
            return false
        end
    end
    return true
end

# n: drone number
# t: current time
function collision(params, start_t, paths, n, t, ndrones)
    for i = 1:ndrones

        collides = false
        if i == n
            continue
        end
        if start_t[i] >= 0  # If drone i was alrady scheduled
            
            n_path_o = mapreduce(permutedims, vcat, paths[i])
            n_path_o = n_path_o[:,1:3]

            # n_path = n_path_o[N,1]'.*ones((N,3))
            # n_path[1:N-start_t[i]+1,:] = n_path_o[start_t[i]:N,:]

            n_path = n_path_o[N,1]'.*ones((N,3))
            n_path[1:N-(t-start_t[i]),:] = n_path_o[t-start_t[i]+1:N,:]

            for k = 1:N
                obst_pos = n_path[k,:]
                dron_pos = paths[n][k][1:3]

                dist = norm(obst_pos - dron_pos)

                if dist < min_dist
                    @printf("DRONE %d: Collision Detected at time %f with drone #%d\n", n, (t+k)*dt, i)
      
                    collides = true
                    return true
                end
            end
        end
    end

    return false
end

# function path_scheduler(params, paths)
#     t = 0
#     start_times = -1* ones(n_drones)
#     start_time[1] = t

#     while !all_scheduled_or_blocked(start_times)
#         for i = 1:n_drones
#             if start_times[i] < 0 
#                 display(i)
#             end
#         end
#     end
# end

# %%
n_drones_t = n_drones
curren_time = 1
drone_to_test = 1
st = Int.(ones(n_drones))
st[1] = -1
collision(params,st, x, drone_to_test, curren_time, n_drones_t)
